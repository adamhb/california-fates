# %% [markdown]
# ### Scratch

# %%
import pandas as pd

# %%
df = pd.read_csv('/glade/work/adamhb/processed_output/CZ2_equilibrium_041924_and_042324_XX.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3072 entries, 0 to 3071
# Columns: 140 entries, Unnamed: 0.1 to param_file_path
# dtypes: float64(123), int64(14), object(3)
# memory usage: 3.3+ MB

# %%
len(df.loc[df['promising'] == 1])
# Out:
# 65

# %%
afterBugFix_1280_041923_df = pd.read_csv('/glade/work/adamhb/processed_output/CZ2_equilibrium_041924_XX_-17e2acb6a_FATES-1449c787/afterBugFix_1280_041923_metrics_and_params.csv')

# %%
afterBugFix_1280_041923_df['Pct_high_severity_1700'].hist()

# %%
afterBugFix_1280_041923_df.loc[afterBugFix_1280_041923_df['promising'] == 1]['fates_fire_nignitions_0'].hist()

# %%
afterBugFix_1280_041923_df.loc[afterBugFix_1280_041923_df['promising'] == 1]['Burned_area'].hist()

# %%
afterBugFix_1280_041923_df['Burned_area'].hist()
