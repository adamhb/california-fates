# %% [markdown]
# ### Script to generate FATES parameters using LHS

# %%
from scipy.stats import qmc
import numpy as np
import csv
import pandas as pd
import os
import netCDF4 as nc4
import sys
import shutil
from tempfile import TemporaryFile                                                                                                                                 
import argparse                                                                                                                                                                                                                                                                                                       
import tempfile 
import random
import re
import modp as mp
from matplotlib import pyplot as plt
from scipy.io import netcdf as nc
import importlib
import math

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# ### Read in min and max values for each parameter and pft
# - Adapted from work by Rachel Ward (parameter ranges and inequalities).
# - Where there are inequalities between PFTx and PFTy, sample PFTx parameter and then use a scalar to generate PFTy parameter. -- If parameter ranges are the same ignore the inequality
# - Add some noise to the inequalities so that inter-PFT trait correlations are not too strict

# %% [markdown]
# ## User-defined params

# %%
path_to_ca_fates = '/glade/u/home/adamhb/california-fates'

# The parameter file used for parameter values that don't vary in the ensemble 
base_param_file_name = 'ca_ahb_5pfts_092123.nc'

# New param file name prefix for the parameter files that do vary
file_name_prefix = 'ca_5pfts_100523'

# Subdir where param files for ensemble are kept
param_files_subdir = 'ca_ahb_5pfts_1512_100823'

# Number of instances
n_inst = 1512

# Path to parameter ranges
param_ranges_full = pd.read_csv(os.path.join(path_to_ca_fates,'parameter_ranges/param_range_archive/param_ranges_100223.csv'))

# %% [markdown]
# ### Pre-process param ranges file

# %%
#path_to_ca_fates = '/home/adam/cloud/gdrive/postdoc/california-fates'

#path_to_base_param_files_root = '/home/adam/cloud/gdrive/postdoc/parameters/'
path_to_base_param_files_root = '/glade/u/home/adamhb/ahb_params/fates_api_25'
#path_to_ensemble_param_files_root = '/home/adam/cloud/gdrive/postdoc/parameters/ensemble_params_test'
path_to_ensemble_param_files_root = '/glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/'

pft_names = ['pine','cedar','fir','shrub','oak']

param_ranges_full = param_ranges_full[['pft_ineq','param', 'value_min', 'value_max', 'pft', 'organ']]

# Filter to params that we are going to sample from the LHS
param_ranges = param_ranges_full.loc[param_ranges_full['pft_ineq'] == 'FALSE']

# Make sure min and max are floats
convert_dict = {'value_min': float,
                'value_max': float
                }
param_ranges = param_ranges.astype(convert_dict)

# number of parameters
n_params = len(param_ranges)
print("Number of params:",n_params)

# number of PFTs - some are global so subtract one
n_pfts = max(len(pd.unique(param_ranges['pft'])) - 1, 1)
print("Number of pfts:", n_pfts)

param_names = list(param_ranges.param)
print("Param names:",param_names)
pfts = list(param_ranges.pft)
organs = list(param_ranges.organ)

param_ranges.info()
# Out:
# Number of params: 63
# Number of pfts: 5
# Param names: ['fates_recruit_seed_alloc_mature', 'fates_recruit_seed_alloc_mature', 'fates_recruit_seed_alloc_mature', 'fates_recruit_seed_dbh_repro_threshold', 'fates_recruit_seed_dbh_repro_threshold', 'fates_fire_alpha_SH', 'fates_fire_alpha_SH', 'fates_fire_alpha_SH', 'fates_fire_bark_scaler', 'fates_fire_bark_scaler', 'fates_fire_bark_scaler', 'fates_fire_crown_kill', 'fates_fire_crown_kill', 'fates_fire_crown_kill', 'fates_fire_drying_ratio', 'fates_fire_nignitions', 'fates_fire_threshold', 'fates_mort_bmort', 'fates_mort_bmort', 'fates_mort_bmort', 'fates_leaf_slatop', 'fates_leaf_slatop', 'fates_leaf_slatop', 'fates_leaf_vcmax25top', 'fates_leaf_vcmax25top', 'fates_leaf_vcmax25top', 'fates_mort_scalar_cstarvation', 'fates_mort_scalar_cstarvation', 'fates_mort_scalar_cstarvation', 'fates_fire_frac_resprout', 'fates_fire_frac_resprout', 'fates_frag_seed_decay_rate', 'fates_frag_seed_decay_rate', 'fates_frag_seed_decay_rate', 'fates_recruit_seed_germination_rate', 'fates_recruit_seed_germination_rate', 'fates_recruit_seed_germination_rate', 'fates_disturbance_germ', 'fates_turnover_branch', 'fates_turnover_branch', 'fates_turnover_leaf', 'fates_turnover_leaf', 'fates_turnover_leaf', 'fates_nonhydro_smpsc', 'fates_nonhydro_smpsc', 'fates_nonhydro_smpsc', 'fates_nonhydro_smpsc', 'fates_nonhydro_smpsc', 'fates_mort_hf_sm_threshold', 'fates_recruit_inter_patch_disp_frac', 'fates_frag_maxdecomp', 'fates_alloc_storage_cushion', 'fates_grperc', 'fates_stoich_nitr', 'fates_stoich_nitr', 'fates_stoich_nitr', 'fates_mort_ip_size_senescence', 'fates_mort_ip_age_senescence', 'fates_allom_d2ca_coefficient_max', 'fates_allom_d2ca_coefficient_max', 'fates_allom_d2ca_coefficient_max', 'fates_allom_agb1', 'fates_allom_agb1']
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pft_ineq   63 non-null     object
#  1   param      63 non-null     object
#  2   value_min  63 non-null     float64
#  3   value_max  63 non-null     float64
#  4   pft        63 non-null     int64
#  5   organ      4 non-null      float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 3.4+ KB

# %%
param_ranges_inequalities = param_ranges_full.loc[param_ranges_full['pft_ineq'] != 'FALSE']

# %%
param_ranges_inequalities
# Out:
#                             pft_ineq                                   param  \
# 1                              <pine         fates_recruit_seed_alloc_mature
# 2                              <pine         fates_recruit_seed_alloc_mature
# 6                               pine  fates_recruit_seed_dbh_repro_threshold
# 7                               pine  fates_recruit_seed_dbh_repro_threshold
# 10                             >pine                     fates_fire_alpha_SH
# 11                             >pine                     fates_fire_alpha_SH
# 15                             <pine                  fates_fire_bark_scaler
# 16                            <cedar                  fates_fire_bark_scaler
# 20                             >pine                   fates_fire_crown_kill
# 21                             >pine                   fates_fire_crown_kill
# 28                              pine                        fates_mort_bmort
# 29                              pine                        fates_mort_bmort
# 33                             >pine                       fates_leaf_slatop
# 34                             cedar                       fates_leaf_slatop
# 37                 fates_leaf_slatop                       fates_leaf_slamax
# 39                             <pine                   fates_leaf_vcmax25top
# 40                            <cedar                   fates_leaf_vcmax25top
# 44                             <pine           fates_mort_scalar_cstarvation
# 45                            <cedar           fates_mort_scalar_cstarvation
# 51                              pine              fates_frag_seed_decay_rate
# 52                              pine              fates_frag_seed_decay_rate
# 56                              pine     fates_recruit_seed_germination_rate
# 57                              pine     fates_recruit_seed_germination_rate
# 62                              pine                   fates_turnover_branch
# 63                              pine                   fates_turnover_branch
# 65                              pine                   fates_turnover_branch
# 67                             >pine                     fates_turnover_leaf
# 68                            >cedar                     fates_turnover_leaf
# 79                             FIXED                    fates_frag_maxdecomp
# 80                             FIXED                    fates_frag_maxdecomp
# 81                             FIXED                    fates_frag_maxdecomp
# 85                             <pine                       fates_stoich_nitr
# 86                            <cedar                       fates_stoich_nitr
# 92                              pine        fates_allom_d2ca_coefficient_max
# 93                              pine        fates_allom_d2ca_coefficient_max
# 96  fates_allom_d2ca_coefficient_max        fates_allom_d2ca_coefficient_min
# 98                              pine                        fates_allom_agb1
# 99                              pine                        fates_allom_agb1
#
#     value_min   value_max  pft  organ
# 1    0.040000    0.392860    2    NaN
# 2    0.040000    0.392860    3    NaN
# 6   10.000000   30.000000    2    NaN
# 7   10.000000   30.000000    3    NaN
# 10   0.100000    0.900000    2    NaN
# 11   0.100000    0.900000    3    NaN
# 15   0.020000    0.080000    2    NaN
# 16   0.020000    0.080000    3    NaN
# 20   0.200000    1.000000    2    NaN
# 21   0.200000    1.000000    3    NaN
# 28   0.002000    0.008000    2    NaN
# 29   0.002000    0.008000    3    NaN
# 33   0.007000    0.017000    2    NaN
# 34   0.007000    0.017000    3    NaN
# 37        NaN         NaN    0    NaN
# 39  45.000000   80.000000    2    NaN
# 40  45.000000   80.000000    3    NaN
# 44   0.050000    0.600000    2    NaN
# 45   0.050000    0.600000    3    NaN
# 51        NaN         NaN    2    NaN
# 52        NaN         NaN    3    NaN
# 56        NaN         NaN    2    NaN
# 57        NaN         NaN    3    NaN
# 62  50.000000  250.000000    2    NaN
# 63  50.000000  250.000000    3    NaN
# 65  50.000000  250.000000    5    NaN
# 67   4.935500   50.000000    2    NaN
# 68   4.935500   50.000000    3    NaN
# 79        NaN    0.736538    0    2.0
# 80        NaN    0.736538    0    3.0
# 81        NaN    1.923077    0    5.0
# 85   0.016000    0.050000    2    1.0
# 86   0.016000    0.050000    3    1.0
# 92   0.256954    0.450000    2    NaN
# 93   0.256954    0.450000    3    NaN
# 96        NaN         NaN    0    NaN
# 98   0.064731    0.084150    2    NaN
# 99   0.064731    0.084150    3    NaN

# %% [markdown]
# ### Sample the parameter space using a Latin Hypercube approach

# %%
sampler = qmc.LatinHypercube(d=n_params, seed=31)
sample = sampler.random(n=n_inst)

# scale to parameter ranges
l_bounds = param_ranges['value_min']
u_bounds = param_ranges['value_max']

scaled_sample = qmc.scale(sample, l_bounds, u_bounds)

print("ensemble dimensions:",scaled_sample.shape)

#Create a dataframe of the LHS ensemble
col_names = [v + "_" + str(p) for v,p in zip(param_names,pfts)]
lhs_df = pd.DataFrame(data=scaled_sample,columns=col_names)
# Out:
# ensemble dimensions: (1512, 63)

# %% [markdown]
# ### Visualize distribution of parameter ranges sampled by the LHS

# %%
# lhs_df['fates_turnover_branch_1'].hist(bins=10, figsize=(20,15))
# plt.show()

# %% [markdown]
# ### Construct parameter files from the LHS samples

# %%
## Read in FATES file with values that will be used for all non-varying parameters

# This parameter file has many changes associated with it compared to the default FATES file
# It also has new parameter added as part of the development required for this experiment.
input_fname = os.path.join(path_to_base_param_files_root,base_param_file_name)

print(input_fname)

# for each sample 
for i in range(0,n_inst) :
    
    param_file_end = str(i+1).rjust(4, '0')
    
    print(param_file_end)
    
    # final parameter file name
    new_file_name = file_name_prefix + '_{0}.nc'.format(param_file_end)
    fout = os.path.join(path_to_ensemble_param_files_root,param_files_subdir,new_file_name)
    
    shutil.copyfile(input_fname, fout)                                                                                                                             
   
    # loop through each parameter and apply either to the correct pft or globally
    for j in range(0, n_params) : 
        
        var = param_names[j]
        pft = pfts[j]
        organ = organs[j]
        
        val = scaled_sample[i, j]
    
        mp.main(var = var, pft = pft, fin = fout, val = val, 
                    fout = fout, O = 1, organ = organ)
# Out:
# /glade/u/home/adamhb/ahb_params/fates_api_25/ca_ahb_5pfts_092123.nc
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# 0137
# 0138
# 0139
# 0140
# 0141
# 0142
# 0143
# 0144
# 0145
# 0146
# 0147
# 0148
# 0149
# 0150
# 0151
# 0152
# 0153
# 0154
# 0155
# 0156
# 0157
# 0158
# 0159
# 0160
# 0161
# 0162
# 0163
# 0164
# 0165
# 0166
# 0167
# 0168
# 0169
# 0170
# 0171
# 0172
# 0173
# 0174
# 0175
# 0176
# 0177
# 0178
# 0179
# 0180
# 0181
# 0182
# 0183
# 0184
# 0185
# 0186
# 0187
# 0188
# 0189
# 0190
# 0191
# 0192
# 0193
# 0194
# 0195
# 0196
# 0197
# 0198
# 0199
# 0200
# 0201
# 0202
# 0203
# 0204
# 0205
# 0206
# 0207
# 0208
# 0209
# 0210
# 0211
# 0212
# 0213
# 0214
# 0215
# 0216
# 0217
# 0218
# 0219
# 0220
# 0221
# 0222
# 0223
# 0224
# 0225
# 0226
# 0227
# 0228
# 0229
# 0230
# 0231
# 0232
# 0233
# 0234
# 0235
# 0236
# 0237
# 0238
# 0239
# 0240
# 0849
# 0850
# 0851
# 0852
# 0853
# 0854
# 0855
# 0856
# 0857
# 0858
# 0859
# 0860
# 0861
# 0862
# 0863
# 0864
# 0865
# 0866
# 0867
# 0868
# 0869
# 0870
# 0871
# 0872
# 0873
# 0874
# 0875
# 0876
# 0877
# 0878
# 0879
# 0880
# 0881
# 0882
# 0883
# 0884
# 0885
# 0886
# 0887
# 0888
# 0889
# 0890
# 0891
# 0892
# 0893
# 0894
# 0895
# 0896
# 0897
# 0898
# 0899
# 0900
# 0901
# 0902
# 0903
# 0904
# 0905
# 0906
# 0907
# 0908
# 0909
# 0910
# 0911
# 0912
# 0913
# 0914
# 0915
# 0916
# 0917
# 0918
# 0919
# 0920
# 0921
# 0922
# 0923
# 0924
# 0925
# 0926
# 0927
# 0928
# 0929
# 0930
# 0931
# 0932
# 0933
# 0934
# 0935
# 0936
# 0937
# 0938
# 0939
# 0940
# 0941
# 0942
# 0943
# 0944
# 0945
# 0946
# 0947
# 0948
# 0949
# 0950
# 0951
# 0952
# 0953
# 0954
# 0955
# 0956
# 0957
# 0958
# 0959
# 0960
# 0961
# 0962
# 0963
# 0964
# 0965
# 0966
# 0967
# 0968
# 0969
# 0970
# 0971
# 0972
# 0973
# 0974
# 0975
# 0976
# 0977
# 0978
# 0979
# 0980
# 0981
# 0982
# 0983
# 0984
# 0985
# 0986
# 0987
# 0988
# 0989
# 0990
# 0991
# 0992
# 0993
# 0994
# 0995
# 0996
# 0997
# 0998
# 0999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# 1157
# 1158
# 1159
# 1160
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# 1169
# 1170
# 1171
# 1172
# 1173
# 1174
# 1175
# 1176
# 1177
# 1178
# 1179
# 1180
# 1181
# 1182
# 1183
# 1184
# 1185
# 1186
# 1187
# 1188
# 1189
# 1190
# 1191
# 1192
# 1193
# 1194
# 1195
# 1196
# 1197
# 1198
# 1199
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1238
# 1239
# 1240
# 1241
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# 1248
# 1249
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# 1259
# 1260
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# 1269
# 1270
# 1271
# 1272
# 1273
# 1274
# 1275
# 1276
# 1277
# 1278
# 1279
# 1280
# 1281
# 1282
# 1283
# 1284
# 1285
# 1286
# 1287
# 1288
# 1289
# 1290
# 1291
# 1292
# 1293
# 1294
# 1295
# 1296
# 1297
# 1298
# 1299
# 1300
# 1301
# 1302
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1448
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# 1486
# 1487
# 1488
# 1489
# 1490
# 1491
# 1492
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499
# 1500
# 1501
# 1502
# 1503
# 1504
# 1505
# 1506
# 1507
# 1508
# 1509
# 1510
# 1511
# 1512

# %% [markdown]
# ### Add values that require a pft-inequality

# %%
def contains_angle_brackets(s):
    return '<' in s or '>' in s

# %%
def get_param_value_from_ineq(ref_pft_value,min_val,max_val,pft_ineq):
    '''returns the parameter value for the pft that depends on a reference pft value'''
    
    if contains_angle_brackets(pft_ineq):
        if ">" in pft_ineq:
            min_val = ref_pft_value
            new_value = np.random.uniform(float(min_val),float(max_val))
        if "<" in pft_ineq:
            max_val = ref_pft_value
            new_value = np.random.uniform(float(min_val),float(max_val))
    else:
        new_value = ref_pft_value
    
    return new_value

def get_ref_pft_index(ineq):  
    for p in pft_names:
        if p in ineq:
            return pft_names.index(p)

def find_files_with_substring(directory, substring):
    """
    Returns a list of filenames in the given directory that contain the given substring.
    
    :param directory: The path to the directory to search in.
    :param substring: The substring to search for in filenames.
    :return: A list of filenames containing the substring.
    """

    # List all files in the directory
    all_files = os.listdir(directory)

    # Filter the ones that contain the substring
    matching_files = [f for f in all_files if substring in f]

    return matching_files


def extract_variable_from_netcdf(file_path, variable_name,pft_index,organ_index):
    """
    Extract a variable from a NetCDF file.

    Parameters:
    - file_path: The path to the NetCDF file.
    - variable_name: The name of the variable to extract.
    - pft index (python index starting at 0)
    - organ index (python index starting at 0)

    Returns:
    - The extracted variable data.
    """
    with nc4.Dataset(file_path, 'r') as dataset:
        # Check if the variable exists in the dataset
        if variable_name in dataset.variables:
            variable_data = dataset.variables[variable_name][:]
            if organ_index == None:
                if len(variable_data.shape) > 1:
                    return variable_data[0,pft_index]
                else:
                    return variable_data[pft_index]
            else:
                return variable_data[organ_index,pft_index]
        else:
            raise ValueError(f"'{variable_name}' not found in the NetCDF file.")

def assign_var_to_nc(file,var,value,pft,organ):
    
    '''
    assigns a value to a netcdf for a particular pft and organ
    
    file = full path to netcdf
    var = fates parameter name
    value = parameter value to add to file
    pft = pft number starting at 1
    organ = organ id starting at 1
    '''
    
    # open nc file
    ncfile = nc.netcdf_file(file, 'a')
    
    # define param of interest
    var = ncfile.variables[var]
    
    # get number of dimensions
    ndim = len(var.dimensions)
    
    if var.dimensions[0] == 'fates_leafage_class':
        #print("using vcmax")
        var[:,int(pft-1)] = value
    
    
    else:
        
        # if ndim > 1 then we have pft and organ
        if ndim > 1:
            #print("using A")
            var[int(organ-1),int(pft-1)] = value

        # if pft = 0 (global), and we specify an organ 
        if (pft == 0) & (not np.isnan(organ)):
            var[(int(organ - 1))] = value
            #print("using B")
        
        # if pft = 0 and organ is NA
        if (pft == 0) & (np.isnan(organ)):
            var[:] = value
            #print("using new one")
        
        # if pft is specified, but organ is not
        if (pft > 0) & (ndim == 1):
            var[(int(pft - 1))] = value
            #print("using C")

# %% [markdown]
# ### Test

# %%
# ref_nc_file = find_files_with_substring(os.path.join(path_to_ensemble_param_files_root,param_files_subdir), "0002")
# print(ref_nc_file[0])
# ref_nc_file_full_path = os.path.join(path_to_ensemble_param_files_root,param_files_subdir,ref_nc_file[0])
# print(ref_nc_file_full_path)

# a = extract_variable_from_netcdf(file_path=ref_nc_file_full_path,
#                              variable_name='fates_frag_maxdecomp',
#                              pft_index=0,organ_index=None)

# a

# with nc4.Dataset(ref_nc_file_full_path, 'r') as dataset:
#     variable_data = dataset.variables["fates_leaf_vcmax25top"][:]
#     print(variable_data[0,0])

# %%
#param_ranges_inequalities.info()

# %%
#Loop through ensemble members

for inst in range(0,n_inst) :
    
    # Get tag
    param_file_end = str(inst+1).rjust(4, '0')
    
    # Get param file with inst tag
    ref_nc_file = find_files_with_substring(directory=os.path.join(path_to_ensemble_param_files_root,
                                                                   param_files_subdir),
                                            substring=param_file_end)
    
    # Get full path of param file
    ref_nc_file_full_path = os.path.join(path_to_ensemble_param_files_root,param_files_subdir,ref_nc_file[0])
    
    print(ref_nc_file_full_path)

    #Loop through parameters
    for i in param_ranges_inequalities.index:

        # input data from the inequalities df
        d = param_ranges_inequalities.loc[i]
        ref_pft_index = get_ref_pft_index(d['pft_ineq'])
        
        #print(d['param'])
        
        #print(ref_pft_index)

        #case where we want one parameter to be the same as another
        if "fates" in d['pft_ineq']:
            
            #print('Case of fates param same as another')
            
            output_val = extract_variable_from_netcdf(file_path=ref_nc_file_full_path,
                                                      variable_name=d['pft_ineq'],
                                                      pft_index=None, organ_index=None)
            assign_var_to_nc(ref_nc_file_full_path,d['param'],output_val,
                             d['pft'],d['organ'])
        #case where we are directly calculating the value
        elif "FIXED" in d['pft_ineq']:
            
            #print('Case FIXED')
            
            # Calculate parameter value
            # In this case the reference parameter is always
            output_val = extract_variable_from_netcdf(file_path=ref_nc_file_full_path,
                                                      variable_name=d['param'],pft_index=0,
                                                      organ_index=None)
            output_val = output_val * d['value_max']
            
            assign_var_to_nc(ref_nc_file_full_path,d['param'],output_val,d['pft'],d['organ'])
        
        #case where we want an inequality between the pfts
        else:
            
            #print('Case inequality')
            
            if math.isnan(d['organ']):
                organ_index = None
            else:
                organ_index = int(d['organ']-1)
            
            ref_pft_value = extract_variable_from_netcdf(ref_nc_file_full_path, d['param'],
                                                         pft_index=ref_pft_index, organ_index=organ_index)
            
            #print(ref_pft_value)
            #print(d['param'])
            
            output_val = get_param_value_from_ineq(ref_pft_value,min_val = d['value_min'],
                                                   max_val = d['value_max'],pft_ineq = d['pft_ineq'])
            
            assign_var_to_nc(ref_nc_file_full_path,d['param'],output_val,d['pft'],d['organ'])
            #print("\n")
# Out:
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0001.nc
# /glade/scratch/adamhb/ipykernel_13252/3274503201.py:79: DeprecationWarning: Please use `netcdf_file` from the `scipy.io` namespace, the `scipy.io.netcdf` namespace is deprecated.
#   ncfile = nc.netcdf_file(file, 'a')
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0002.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0003.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0004.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0005.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0006.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0007.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0008.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0009.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0010.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0011.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0012.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0013.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0014.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0015.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0016.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0017.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0018.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0019.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0020.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0021.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0022.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0023.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0024.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0025.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0026.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0027.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0028.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0029.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0030.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0031.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0032.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0033.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0034.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0035.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0036.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0037.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0038.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0039.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0040.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0041.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0042.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0043.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0044.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0045.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0046.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0047.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0048.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0049.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0050.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0051.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0675.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0053.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0054.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0055.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0056.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0057.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0058.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0059.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0060.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0061.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0062.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0063.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0064.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0065.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0066.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0067.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0068.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0069.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0070.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0071.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0072.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0073.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0074.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0075.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0076.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0077.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0078.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0079.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0080.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0081.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0082.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0083.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0084.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0085.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0086.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0087.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0088.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0089.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0090.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0091.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0092.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0093.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0094.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0095.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0096.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0097.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0098.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0099.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0100.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0101.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0102.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0103.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0104.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0105.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0106.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0107.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0108.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0109.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0110.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0111.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0112.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0113.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0114.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0115.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0116.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0117.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0118.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0119.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0120.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0121.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0122.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0123.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0124.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0125.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0126.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0127.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0128.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0129.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0130.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0131.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0132.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0133.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0134.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0135.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0136.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0137.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0138.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0139.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0140.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0141.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0142.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0143.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0144.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0145.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0146.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0147.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0148.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0149.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0150.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0151.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0152.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0153.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0154.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0155.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0156.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0157.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0158.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0159.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0160.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0161.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0162.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0163.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0164.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0165.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0166.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0167.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0168.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0169.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0170.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0171.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0172.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0173.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0174.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0175.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0176.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0177.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0178.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0179.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0180.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0181.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0182.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0183.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0184.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0185.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0186.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0187.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0188.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0189.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0190.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0191.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0192.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0193.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0194.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0195.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0196.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0197.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0198.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0199.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0200.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0201.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0202.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0203.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0204.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0205.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0206.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0207.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0208.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0209.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0210.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0211.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0212.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0213.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0214.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0215.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0216.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0217.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0218.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0219.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0220.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0221.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0222.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0223.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0224.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0225.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0226.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0227.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0228.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0229.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0230.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0231.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0232.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0233.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0234.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0235.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0236.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0237.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0238.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0239.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0240.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0241.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0242.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_0243.nc
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/ca_ahb_5pfts_1512_100823/ca_5pfts_100523_