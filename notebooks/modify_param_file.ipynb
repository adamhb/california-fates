# %%
import shutil
import pandas as pd
import glob
import os
import netCDF4 as nc4
import sys
sys.path.append('/glade/u/home/adamhb/Earth-System-Model-Tools')
import esm_tools

# %%
param_dir = '/glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524'

# %%
for param_file in sorted(glob.glob(os.path.join(param_dir,'*.nc'))):
    print(param_file)
    esm_tools.assign_variable_to_netcdf(param_file, "fates_fire_nignitions", 0.0356)
    esm_tools.assign_variable_to_netcdf(param_file, "fates_fire_threshold", 1700)
# Out:
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524/ca_5pfts_100523_0001.nc
# Changed fates_fire_nignitions to 0.0356
# Changed fates_fire_threshold to 1700
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524/ca_5pfts_100523_0002.nc
# Changed fates_fire_nignitions to 0.0356
# Changed fates_fire_threshold to 1700
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524/ca_5pfts_100523_0003.nc
# Changed fates_fire_nignitions to 0.0356
# Changed fates_fire_threshold to 1700
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524/ca_5pfts_100523_0004.nc
# Changed fates_fire_nignitions to 0.0356
# Changed fates_fire_threshold to 1700
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524/ca_5pfts_100523_0005.nc
# Changed fates_fire_nignitions to 0.0356
# Changed fates_fire_threshold to 1700
# /glade/u/home/adamhb/ahb_params/fates_api_25/ensembles/sup_042524/ca_5pfts_100523_0006.nc
# Changed fates_fire_nignitions to 0.0356
# ...
