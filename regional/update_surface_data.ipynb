# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.feature import NaturalEarthFeature, LAND, COASTLINE
import numpy as np
import geopandas as gpd
from shapely.geometry import Point
import pandas as pd
import pygeos
import math
from shapely.geometry import Polygon
import netCDF4

# %% [markdown]
# ## Import data

# %%
# Surf data on correct (WRF) grid
wrf_surfdat_path = "surfdata_wrf_CA_hist_16pfts_CMIP6_1981_c220715.nc"

# Surf data with correct values
surfdat_path = "CA_surfdat_211202.nc"

# Domain
target_domain = gpd.read_file("target_domain_111623.shp") # CZ transect

# California boundary
path_to_ca = '/home/adam/cloud/gdrive/fire_project/local_data/ca-state-boundary/CA_State_TIGER2016.shp'

# %% [markdown]
# ## Create bounding box of Polly's surface data

# %%
# top_left = (surfdat["LATIXY"].values.max(), surfdat["LONGXY"].values.min())  # Latitude and longitude for the top-left corner
# bottom_right = (surfdat["LATIXY"].values.min(), surfdat["LONGXY"].values.max())  # Latitude and longitude for the bottom-right corner

# # Create a Polygon representing the bounding box
# bounding_box = Polygon([(top_left[1], top_left[0]), (bottom_right[1], top_left[0]),
#                         (bottom_right[1], bottom_right[0]), (top_left[1], bottom_right[0])])

# %% [markdown]
# ## Visualize Polly's surface data

# %%
# ca = gpd.read_file(path_to_ca).to_crs(target_domain.crs)

# fig, ax = plt.subplots(figsize=(15, 15))

# # Add california
# ca.plot(ax = ax, facecolor="none", edgecolor='black', lw=0.7)

# # Add target domain
# target_domain.plot(ax = ax,facecolor="none", edgecolor='black', lw=0.7)

# # Add bounding box of Polly's surface data
# gdf_polly_bounding = gpd.GeoDataFrame({'geometry': [bounding_box]})
# gdf_polly_bounding.plot(ax = ax, alpha = 0.1)

# # Points to view on map
# points = gpd.points_from_xy([-119.978773,-119.988773,-119.26531432946383],
#                             [38.17940086346834,38.18940086346834,37.032763507337556], z=None, crs="EPSG:4326")

# # Create geodataframe of points to put on map
# df_shell = pd.DataFrame({'id':[0,1,2]})
# gdf_points = gpd.GeoDataFrame(df_shell, geometry=points)
# gdf_points.plot(ax = ax)

# %% [markdown]
# ## Functions

# %%
# def find_nearest_index(lat, lon, lat_array, lon_array):
#     """
#     Find the nearest lsmlat and lsmlon indices for a given latitude and longitude.

#     :param lat: Latitude of the point to find.
#     :param lon: Longitude of the point to find.
#     :param lat_array: 2D array of latitudes from the NetCDF file.
#     :param lon_array: 2D array of longitudes from the NetCDF file.
#     :return: Tuple of (lsmlat_index, lsmlon_index).
#     """
#     # Calculate the square of the Euclidean distance
#     dist_sq = (lat_array - lat)**2 + (lon_array - lon)**2

#     # Find the index of the minimum distance
#     lsmlat_index, lsmlon_index = np.unravel_index(np.argmin(dist_sq), dist_sq.shape)
#     return lsmlat_index, lsmlon_index

# # Load NetCDF file
# nc_file = netCDF4.Dataset('CA_surfdat_211202.nc', 'r')

# # Extract LATIXY and LONGXY
# lat_array = nc_file.variables['LATIXY'][:]
# lon_array = nc_file.variables['LONGXY'][:] - 360

# # Example usage
# latitude = 37.0311  # Replace with your latitude
# longitude = -119.256599  # Replace with your longitude
# nearest_lsmlat, nearest_lsmlon = find_nearest_index(latitude, longitude, lat_array, lon_array)

# print("Nearest lsmlat index:", nearest_lsmlat)
# print("Nearest lsmlon index:", nearest_lsmlon)

# %%
# def find_nearest_wrf_indices(wrf_grid_data,target_lat,target_lon):
    
#     # Get shape of WRF grid
#     wrf_grid_2D_shape = wrf_grid_data['LATIXY'].values.shape
#     print(wrf_grid_2D_shape)
#     wrf_grid_1D_shape = wrf_grid_2D_shape[0] * wrf_grid_2D_shape[1]
    
#     # numpy array of wrf coordinate (LAT,LONG)
#     wrf_coordinates = np.array((wrf_grid_data['LATIXY'].values.reshape(wrf_grid_1D_shape),
#                                 wrf_grid_data['LONGXY'].values.reshape(wrf_grid_1D_shape)))

#     distances = np.sqrt( (wrf_coordinates[0,:] - target_lat)**2  \
#                         + (wrf_coordinates[1,:] - target_lon)**2 \
#                        )
    
#     # Get index of closest point
#     wrf_1D_index = np.argmin(distances)
#     wrf_2D_row_index = wrf_1D_index // wrf_grid_2D_shape[0]
#     wrf_2D_col_index = wrf_1D_index % wrf_grid_2D_shape[0]
    
#     return wrf_2D_row_index,wrf_2D_col_index

def find_nearest_indices(nc_file_path, target_lat, target_lon):
    """
    Find the nearest lsmlat and lsmlon indices for a given latitude and longitude in a NetCDF file.

    :param nc_file_path: Path to the NetCDF file.
    :param target_lat: Target latitude.
    :param target_lon: Target longitude.
    :return: Tuple of (lsmlat_index, lsmlon_index).
    """
    # Load NetCDF file
    with netCDF4.Dataset(nc_file_path, 'r') as nc_file:
        # Extract LATIXY and LONGXY
        lat_array = nc_file.variables['LATIXY'][:]
        lon_array = nc_file.variables['LONGXY'][:]

    if np.max(lon_array) > 180:
        lon_array = lon_array - 360
        print("Made conversion to -180 to 180 scale")
        
    # Calculate the square of the Euclidean distance
    dist_sq = (lat_array - target_lat)**2 + (lon_array - target_lon)**2

    # Find the index of the minimum distance
    lsmlat_index, lsmlon_index = np.unravel_index(np.argmin(dist_sq), dist_sq.shape)
    return lsmlat_index, lsmlon_index


def is_point_in_polygon(point_coordinates, polygon):
    # Create a Point object for the coordinates
    point = Point(point_coordinates)
    
    # Check if the Point is within the Polygon
    return point.within(polygon)


def update_surf_dat_in_wrf_surf_file(wrf_surfdat_path,
                                     surfdat_path,
                                     target_domain,
                                     vars_to_subtitute = ['SOIL_COLOR','PCT_SAND','PCT_CLAY','ORGANIC']):

    
    '''
    
    The function substitutes values of surface data varibales from a data set with correct values (surfdat_path)
    to a dataset that is already correctly formated on a wrf grid.
    
    param wrf_surfdat_path: path to the surface data that is on a wrf grid that you want to modify.
    param surfdat_path: path to the surface data with the correct values you want to use
    param target_domain: geopandas.geodataframe.GeoDataFrame holding a polygon with the target domain
                         for substituting data.
    param vars_substitute: list of variable names that you want substituded
    
    '''
    
    # Import wrf surface data
    wrf_surfdat = xr.open_dataset(wrf_surfdat_path)
    
    # Rescale from 0:360 to -180:180
    if np.max(wrf_surfdat['LONGXY'].values) > 180:
        wrf_surfdat['LONGXY'] = wrf_surfdat['LONGXY'] - 360
        print("Converting to -180 to 180 scale")
    
    # Create new wrf surface data to alter
    new_wrf_surfdat = wrf_surfdat.copy()
    
    # Import surface data with correct values
    surfdat = xr.open_dataset(surfdat_path)
    
    # Rescale from 0:360 to -180:180
    if np.max(surfdat['LONGXY'].values) > 180:
        surfdat['LONGXY'] = surfdat['LONGXY'] - 360
        print("Converting to -180 to 180 scale")
    
    
    # Loop through wrf data points within the target domain
    # to update each point with the correct surface data
    
    
    new_wrf_surf_dat_2D_shape = new_wrf_surfdat['LATIXY'].values.shape
    i = 0
    
    for wrf_row in range(new_wrf_surf_dat_2D_shape[0]):
        for wrf_col in range(new_wrf_surf_dat_2D_shape[1]):

            target_lat = new_wrf_surfdat["LATIXY"].values[wrf_row,wrf_col]
            target_lon = new_wrf_surfdat["LONGXY"].values[wrf_row,wrf_col]

            # Check if lat/lon is in target domain
            if is_point_in_polygon((target_lon,target_lat),target_domain.geometry[0]):
                i = i + 1
                
                print("Working on point",i,"in target domain")
                
                print("Target lat:",target_lat)
                print("Target log:",target_lon)
                
                # Get the surface data indices where the data should be substituted into the new WRF data
                surf_row, surf_col = find_nearest_indices(surfdat_path,target_lat,target_lon)
                
                for var in vars_to_subtitute:
                    
                    if surfdat[var].dims == ('nlevsoi', 'lsmlat', 'lsmlon'):
                        print("Getting data from surface data",surf_row, surf_col,"to put in wrf",wrf_row,wrf_col)
                        new_values = surfdat[var].values[:,surf_row,surf_col]
                        new_wrf_surfdat[var].values[:,wrf_row,wrf_col] = new_values

                    elif surfdat[var].dims == ('lsmlat', 'lsmlon'):
                        new_values = surfdat[var].values[surf_row,surf_col]
                        new_wrf_surfdat[var].values[wrf_row,wrf_col] = new_values
                        
                    else:
                        print("Variable",var,"has unknown dimensions. Skipping")
                        continue
            else:
                continue
    return new_wrf_surfdat

# %% [markdown]
# ## Apply to new wrf surf data

# %%
# %%time
new_wrf_xds = update_surf_dat_in_wrf_surf_file(wrf_surfdat_path,
                                 surfdat_path,
                                 target_domain)
# Out:
# Converting to -180 to 180 scale
# Working on point 1 in target domain
# Target lat: 36.67720413208008
# Target log: -119.38523864746094
# Made conversion to -180 to 180 scale
# Getting data from surface data 102 121 to put in wrf 71 70
# Getting data from surface data 102 121 to put in wrf 71 70
# Getting data from surface data 102 121 to put in wrf 71 70
# Working on point 2 in target domain
# Target lat: 36.7250862121582
# Target log: -119.3009033203125
# Made conversion to -180 to 180 scale
# Getting data from surface data 103 123 to put in wrf 71 71
# Getting data from surface data 103 123 to put in wrf 71 71
# Getting data from surface data 103 123 to put in wrf 71 71
# Working on point 3 in target domain
# Target lat: 36.74477767944336
# Target log: -119.44505310058594
# Made conversion to -180 to 180 scale
# Getting data from surface data 103 120 to put in wrf 72 70
# Getting data from surface data 103 120 to put in wrf 72 70
# Getting data from surface data 103 120 to put in wrf 72 70
# Working on point 4 in target domain
# Target lat: 36.792724609375
# Target log: -119.36067199707031
# Made conversion to -180 to 180 scale
# Getting data from surface data 105 122 to put in wrf 72 71
# Getting data from surface data 105 122 to put in wrf 72 71
# Getting data from surface data 105 122 to put in wrf 72 71
# Working on point 5 in target domain
# Target lat: 36.840599060058594
# Target log: -119.27618408203125
# Made conversion to -180 to 180 scale
# Getting data from surface data 106 124 to put in wrf 72 72
# Getting data from surface data 106 124 to put in wrf 72 72
# Getting data from surface data 106 124 to put in wrf 72 72
# Working on point 6 in target domain
# Target lat: 36.88842010498047
# Target log: -119.19155883789062
# Made conversion to -180 to 180 scale
# Getting data from surface data 107 126 to put in wrf 72 73
# Getting data from surface data 107 126 to put in wrf 72 73
# Getting data from surface data 107 126 to put in wrf 72 73
# Working on point 7 in target domain
# Target lat: 36.93617248535156
# Target log: -119.1068115234375
# Made conversion to -180 to 180 scale
# Getting data from surface data 108 128 to put in wrf 72 74
# Getting data from surface data 108 128 to put in wrf 72 74
# Getting data from surface data 108 128 to put in wrf 72 74
# Working on point 8 in target domain
# Target lat: 36.81232833862305
# Target log: -119.50498962402344
# Made conversion to -180 to 180 scale
# Getting data from surface data 105 118 to put in wrf 73 70
# Getting data from surface data 105 118 to put in wrf 73 70
# Getting data from surface data 105 118 to put in wrf 73 70
# Working on point 9 in target domain
# Target lat: 36.860328674316406
# Target log: -119.42057800292969
# Made conversion to -180 to 180 scale
# Getting data from surface data 106 120 to put in wrf 73 71
# Getting data from surface data 106 120 to put in wrf 73 71
# Getting data from surface data 106 120 to put in wrf 73 71
# Working on point 10 in target domain
# Target lat: 36.908267974853516
# Target log: -119.33602905273438
# Made conversion to -180 to 180 scale
# Getting data from surface data 107 122 to put in wrf 73 72
# Getting data from surface data 107 122 to put in wrf 73 72
# Getting data from surface data 107 122 to put in wrf 73 72
# Working on point 11 in target domain
# Target lat: 36.95614242553711
# Target log: -119.25135803222656
# Made conversion to -180 to 180 scale
# Getting data from surface data 108 124 to put in wrf 73 73
# Getting data from surface data 108 124 to put in wrf 73 73
# Getting data from surface data 108 124 to put in wrf 73 73
# Working on point 12 in target domain
# Target lat: 37.00394821166992
# Target log: -119.16656494140625
# Made conversion to -180 to 180 scale
# Getting data from surface data 110 127 to put in wrf 73 74
# Getting data from surface data 110 127 to put in wrf 73 74
# Getting data from surface data 110 127 to put in wrf 73 74
# Working on point 13 in target domain
# Target lat: 37.05168533325195
# Target log: -119.08163452148438
# Made conversion to -180 to 180 scale
# Getting data from surface data 111 129 to put in wrf 73 75
# Getting data from surface data 111 129 to put in wrf 73 75
# Getting data from surface data 111 129 to put in wrf 73 75
# Working on point 14 in target domain
# Target lat: 37.09935760498047
# Target log: -118.99659729003906
# Made conversion to -180 to 180 scale
# Getting data from surface data 112 131 to put in wrf 73 76
# Getting data from surface data 112 131 to put in wrf 73 76
# Getting data from surface data 112 131 to put in wrf 73 76
# Working on point 15 in target domain
# Target lat: 36.879844665527344
# Target log: -119.5650634765625
# Made conversion to -180 to 180 scale
# Getting data from surface data 107 117 to put in wrf 74 70
# Getting data from surface data 107 117 to put in wrf 74 70
# Getting data from surface data 107 117 to put in wrf 74 70
# Working on point 16 in target domain
# Target lat: 36.92790603637695
# Target log: -119.4805908203125
# Made conversion to -180 to 180 scale
# Getting data from surface data 108 119 to put in wrf 74 71
# Getting data from surface data 108 119 to put in wrf 74 71
# Getting data from surface data 108 119 to put in wrf 74 71
# Working on point 17 in target domain
# Target lat: 36.97589874267578
# Target log: -119.39599609375
# Made conversion to -180 to 180 scale
# Getting data from surface data 109 121 to put in wrf 74 72
# Getting data from surface data 109 121 to put in wrf 74 72
# Getting data from surface data 109 121 to put in wrf 74 72
# Working on point 18 in target domain
# Target lat: 37.02383804321289
# Target log: -119.311279296875
# Made conversion to -180 to 180 scale
# Getting data from surface data 110 123 to put in wrf 74 73
# Getting data from surface data 110 123 to put in wrf 74 73
# Getting data from surface data 110 123 to put in wrf 74 73
# Working on point 19 in target domain
# Target lat: 37.07170104980469
# Target log: -119.22645568847656
# Made conversion to -180 to 180 scale
# Getting data from surface data 111 125 to put in wrf 74 74
# Getting data from surface data 111 125 to put in wrf 74 74
# Getting data from surface data 111 125 to put in wrf 74 74
# Working on point 20 in target domain
# Target lat: 37.11949920654297
# Target log: -119.1414794921875
# Made conversion to -180 to 180 scale
# Getting data from surface data 112 127 to put in wrf 74 75
# Getting data from surface data 112 127 to put in wrf 74 75
# Getting data from surface data 112 127 to put in wrf 74 75
# Working on point 21 in target domain
# Target lat: 37.1672248840332
# Target log: -119.05638122558594
# Made conversion to -180 to 180 scale
# Getting data from surface data 114 129 to put in wrf 74 76
# Getting data from surface data 114 129 to put in wrf 74 76
# Getting data from surface data 114 129 to put in wrf 74 76
# Working on point 22 in target domain
# Target lat: 37.21489715576172
# Target log: -118.97116088867188
# Made conversion to -180 to 180 scale
# Getting data from surface data 115 131 to put in wrf 74 77
# Getting data from surface data 115 131 to put in wrf 74 77
# Getting data from surface data 115 131 to put in wrf 74 77
# Working on point 23 in target domain
# Target lat: 37.26249313354492
# Target log: -118.88580322265625
# Made conversion to -180 to 180 scale
# Getting data from surface data 116 133 to put in wrf 74 78
# Getting data from surface data 116 133 to put in wrf 74 78
# Getting data from surface data 116 133 to put in wrf 74 78
# Working on point 24 in target domain
# Target lat: 37.310028076171875
# Target log: -118.80032348632812
# Made conversion to -180 to 180 scale
# Getting data from surface data 117 135 to put in wrf 74 79
# Getting data from surface data 117 135 to put in wrf 74 79
# Getting data from surface data 117 135 to put in wrf 74 79
# Working on point 25 in target domain
# Target lat: 36.89916229248047
# Target log: -119.70962524414062
# Made conversion to -180 to 180 scale
# Getting data from surface data 107 113 to put in wrf 75 69
# Getting data from surface data 107 113 to put in wrf 75 69
# Getting data from surface data 107 113 to put in wrf 75 69
# Working on point 26 in target domain
# Target lat: 36.94734191894531
# Target log: -119.625244140625
# Made conversion to -180 to 180 scale
# Getting data from surface data 108 115 to put in wrf 75 70
# Getting data from surface data 108 115 to put in wrf 75 70
# Getting data from surface data 108 115 to put in wrf 75 70
# Working on point 27 in target domain
# Target lat: 36.99546813964844
# Target log: -119.54074096679688
# Made conversion to -180 to 180 scale
# Getting data from surface data 109 118 to put in wrf 75 71
# Getting data from surface data 109 118 to put in wrf 75 71
# Getting data from surface data 109 118 to put in wrf 75 71
# Working on point 28 in target domain
# Target lat: 37.043521881103516
# Target log: -119.45610046386719
# Made conversion to -180 to 180 scale
# Getting data from surface data 111 120 to put in wrf 75 72
# Getting data from surface data 111 120 to put in wrf 75 72
# Getting data from surface data 111 120 to put in wrf 75 72
# Working on point 29 in target domain
# Target lat: 37.09151077270508
# Target log: -119.37135314941406
# Made conversion to -180 to 180 scale
# Getting data from surface data 112 122 to put in wrf 75 73
# Getting data from surface data 112 122 to put in wrf 75 73
# Getting data from surface data 112 122 to put in wrf 75 73
# Working on point 30 in target domain
# Target lat: 37.13943099975586
# Target log: -119.28645324707031
# Made conversion to -180 to 180 scale
# Getting data from surface data 113 124 to put in wrf 75 74
# Getting data from surface data 113 124 to put in wrf 75 74
# Getting data from surface data 113 124 to put in wrf 75 74
# Working on point 31 in target domain
# Target lat: 37.187294006347656
# Target log: -119.20144653320312
# Made conversion to -180 to 180 scale
# Getting data from surface data 114 126 to put in wrf 75 75
# Getting data from surface data 114 126 to put in wrf 75 75
# Getting data from surface data 114 126 to put in wrf 75 75
# Working on point 32 in target domain
# Target lat: 37.23508834838867
# Target log: -119.11630249023438
# Made conversion to -180 to 180 scale
# Getting data from surface data 115 128 to put in wrf 75 76
# Getting data from surface data 115 128 to put in wrf 75 76
# Getting data from surface data 115 128 to put in wrf 75 76
# Working on point 33 in target domain
# Target lat: 37.28281021118164
# Target log: -119.03103637695312
# Made conversion to -180 to 180 scale
# Getting data from surface data 116 130 to put in wrf 75 77
# Getting data from surface data 116 130 to put in wrf 75 77
# Getting data from surface data 116 130 to put in wrf 75 77
# Working on point 34 in target domain
# Target lat: 37.330467224121094
# Target log: -118.94564819335938
# Made conversion to -180 to 180 scale
# Getting data from surface data 117 132 to put in wrf 75 78
# Getting data from surface data 117 132 to put in wrf 75 78
# Getting data from surface data 117 132 to put in wrf 75 78
# Working on point 35 in target domain
# Target lat: 37.378055572509766
# Target log: -118.860107421875
# Made conversion to -180 to 180 scale
# Getting data from surface data 119 134 to put in wrf 75 79
# Getting data from surface data 119 134 to put in wrf 75 79
# Getting data from surface data 119 134 to put in wrf 75 79
# Working on point 36 in target domain
# Target lat: 36.96657180786133
# Target log: -119.76998901367188
# Made conversion to -180 to 180 scale
# Getting data from surface data 109 112 to put in wrf 76 69
# Getting data from surface data 109 112 to put in wrf 76 69
# Getting data from surface data 109 112 to put in wrf 76 69
# Working on point 37 in target domain
# Target lat: 37.01481246948242
# Target log: -119.68556213378906
# Made conversion to -180 to 180 scale
# Getting data from surface data 110 114 to put in wrf 76 70
# Getting data from surface data 110 114 to put in wrf 76 70
# Getting data from surface data 110 114 to put in wrf 76 70
# Working on point 38 in target domain
# Target lat: 37.062992095947266
# Target log: -119.60101318359375
# Made conversion to -180 to 180 scale
# Getting data from surface data 111 116 to put in wrf 76 71
# Getting data from surface data 111 116 to put in wrf 76 71
# Getting data from surface data 111 116 to put in wrf 76 71
# Working on point 39 in target domain
# Target lat: 37.11111068725586
# Target log: -119.51632690429688
# Made conversion to -180 to 180 scale
# Getting data from surface data 112 118 to put in wrf 76 72
# Getting data from surface data 112 118 to put in wrf 76 72
# Getting data from surface data 112 118 to put in wrf 76 72
# Working on point 40 in target domain
# Target lat: 37.15916061401367
# Target log: -119.43153381347656
# Made conversion to -180 to 180 scale
# Getting data from surface data 113 120 to put in wrf 76 73
# Getting data from surface data 113 120 to put in wrf 76 73
# Getting data from surface data 113 120 to put in wrf 76 73
# Working on point 41 in target domain
# Target lat: 37.20714569091797
# Target log: -119.34660339355469
# Made conversion to -180 to 180 scale
# Getting data from surface data 114 122 to put in wrf 76 74
# Getting data from surface data 114 122 to put in wrf 76 74
# Getting data from surface data 114 122 to put in wrf 76 74
# Working on point 42 in target domain
# Target lat: 37.25505447387695
# Target log: -119.26153564453125
# Made conversion to -180 to 180 scale
# Getting data from surface data 116 124 to put in wrf 76 75
# Getting data from surface data 116 124 to put in wrf 76 75
# Getting data from surface data 116 124 to put in wrf 76 75
# Working on point 43 in target domain
# Target lat: 37.30290603637695
# Target log: -119.17636108398438
# Made conversion to -180 to 180 scale
# Getting data from surface data 117 126 to put in wrf 76 76
# Getting data from surface data 117 126 to put in wrf 76 76
# Getting data from surface data 117 126 to put in wrf 76 76
# Working on point 44 in target domain
# Target lat: 37.35068893432617
# Target log: -119.09103393554688
# Made conversion to -180 to 180 scale
# Getting data from surface data 118 128 to put in wrf 76 77
# Getting data from surface data 118 128 to put in wrf 76 77
# Getting data from surface data 118 128 to put in wrf 76 77
# Working on point 45 in target domain
# Target lat: 37.398406982421875
# Target log: -119.00559997558594
# Made conversion to -180 to 180 scale
# Getting data from surface data 119 130 to put in wrf 76 78
# Getting data from surface data 119 130 to put in wrf 76 78
# Getting data from surface data 119 130 to put in wrf 76 78
# Working on point 46 in target domain
# Target lat: 37.44606018066406
# Target log: -118.92002868652344
# Made conversion to -180 to 180 scale
# Getting data from surface data 120 132 to put in wrf 76 79
# Getting data from surface data 120 132 to put in wrf 76 79
# Getting data from surface data 120 132 to put in wrf 76 79
# Working on point 47 in target domain
# Target lat: 37.03395462036133
# Target log: -119.83047485351562
# Made conversion to -180 to 180 scale
# Getting data from surface data 110 111 to put in wrf 77 69
# Getting data from surface data 110 111 to put in wrf 77 69
# Getting data from surface data 110 111 to put in wrf 77 69
# Working on point 48 in target domain
# Target lat: 37.08225631713867
# Target log: -119.74600219726562
# Made conversion to -180 to 180 scale
# Getting data from surface data 111 113 to put in wrf 77 70
# Getting data from surface data 111 113 to put in wrf 77 70
# Getting data from surface data 111 113 to put in wrf 77 70
# Working on point 49 in target domain
# Target lat: 37.130496978759766
# Target log: -119.66140747070312
# Made conversion to -180 to 180 scale
# Getting data from surface data 113 115 to put in wrf 77 71
# Getting data from surface data 113 115 to put in wrf 77 71
# Getting data from surface data 113 115 to put in wrf 77 71
# Working on point 50 in target domain
# Target lat: 37.17866516113281
# Target log: -119.57669067382812
# Made conversion to -180 to 180 scale
# Getting data from surface data 114 117 to put in wrf 77 72
# Getting data from surface data 114 117 to put in wrf 77 72
# Getting data from surface data 114 117 to put in wrf 77 72
# Working on point 51 in target domain
# Target lat: 37.22677993774414
# Target log: -119.49185180664062
# Made conversion to -180 to 180 scale
# Getting data from surface data 115 119 to put in wrf 77 73
# Getting data from surface data 115 119 to put in wrf 77 73
# Getting data from surface data 115 119 to put in wrf 77 73
# Working on point 52 in target domain
# Target lat: 37.27482223510742
# Target log: -119.40687561035156
# Made conversion to -180 to 180 scale
# Getting data from surface data 116 121 to put in wrf 77 74
# Getting data from surface data 116 121 to put in wrf 77 74
# Getting data from surface data 116 121 to put in wrf 77 74
# Working on point 53 in target domain
# Target lat: 37.32280349731445
# Target log: -119.32176208496094
# Made conversion to -180 to 180 scale
# Getting data from surface data 117 123 to put in wrf 77 75
# Getting data from surface data 117 123 to put in wrf 77 75
# Getting data from surface data 117 123 to put in wrf 77 75
# Working on point 54 in target domain
# Target lat: 37.370704650878906
# Target log: -119.23652648925781
# Made conversion to -180 to 180 scale
# Getting data from surface data 118 125 to put in wrf 77 76
# Getting data from surface data 118 125 to put in wrf 77 76
# Getting data from surface data 118 125 to put in wrf 77 76
# Working on point 55 in target domain
# Target lat: 37.41854476928711
# Target log: -119.15116882324219
# Made conversion to -180 to 180 scale
# Getting data from surface data 120 127 to put in wrf 77 77
# Getting data from surface data 120 127 to put in wrf 77 77
# Getting data from surface data 120 127 to put in wrf 77 77
# Working on point 56 in target domain
# Target lat: 37.4663200378418
# Target log: -119.065673828125
# Made conversion to -180 to 180 scale
# Getting data from surface data 121 129 to put in wrf 77 78
# Getting data from surface data 121 129 to put in wrf 77 78
# Getting data from surface data 121 129 to put in wrf 77 78
# Working on point 57 in target domain
# Target lat: 37.51403045654297
# Target log: -118.98007202148438
# Made conversion to -180 to 180 scale
# Getting data from surface data 122 131 to put in wrf 77 79
# Getting data from surface data 122 131 to put in wrf 77 79
# Getting data from surface data 122 131 to put in wrf 77 79
# Working on point 58 in target domain
# Target lat: 37.19797897338867
# Target log: -119.72193908691406
# Made conversion to -180 to 180 scale
# Getting data from surface data 114 113 to put in wrf 78 71
# Getting data from surface data 114 113 to put in wrf 78 71
# Getting data from surface data 114 113 to put in wrf 78 71
# Working on point 59 in target domain
# Target lat: 37.246212005615234
# Target log: -119.63717651367188
# Made conversion to -180 to 180 scale
# Getting data from surface data 115 115 to put in wrf 78 72
# Getting data from surface data 115 115 to put in wrf 78 72
# Getting data from surface data 115 115 to put in wrf 78 72
# Working on point 60 in target domain
# Target lat: 37.29438400268555
# Target log: -119.55229187011719
# Made conversion to -180 to 180 scale
# Getting data from surface data 117 117 to put in wrf 78 73
# Getting data from surface data 117 117 to put in wrf 78 73
# Getting data from surface data 117 117 to put in wrf 78 73
# Working on point 61 in target domain
# Target lat: 37.34248352050781
# Target log: -119.46725463867188
# Made conversion to -180 to 180 scale
# Getting data from surface data 118 119 to put in wrf 78 74
# Getting data from surface data 118 119 to put in wrf 78 74
# Getting data from surface data 118 119 to put in wrf 78 74
# Working on point 62 in target domain
# Target lat: 37.3905143737793
# Target log: -119.38211059570312
# Made conversion to -180 to 180 scale
# Getting data from surface data 119 121 to put in wrf 78 75
# Getting data from surface data 119 121 to put in wrf 78 75
# Getting data from surface data 119 121 to put in wrf 78 75
# Working on point 63 in target domain
# Target lat: 37.4384765625
# Target log: -119.29684448242188
# Made conversion to -180 to 180 scale
# Getting data from surface data 120 123 to put in wrf 78 76
# Getting data from surface data 120 123 to put in wrf 78 76
# Getting data from surface data 120 123 to put in wrf 78 76
# Working on point 64 in target domain
# Target lat: 37.48638153076172
# Target log: -119.21142578125
# Made conversion to -180 to 180 scale
# Getting data from surface data 121 125 to put in wrf 78 77
# Getting data from surface data 121 125 to put in wrf 78 77
# Getting data from surface data 121 125 to put in wrf 78 77
# Working on point 65 in target domain
# Target lat: 37.53421401977539
# Target log: -119.12590026855469
# Made conversion to -180 to 180 scale
# Getting data from surface data 122 127 to put in wrf 78 78
# Getting data from surface data 122 127 to put in wrf 78 78
# Getting data from surface data 122 127 to put in wrf 78 78
# Working on point 66 in target domain
# Target lat: 37.58197784423828
# Target log: -119.04023742675781
# Made conversion to -180 to 180 scale
# Getting data from surface data 123 130 to put in wrf 78 79
# Getting data from surface data 123 130 to put in wrf 78 79
# Getting data from surface data 123 130 to put in wrf 78 79
# Working on point 67 in target domain
# Target lat: 37.41011047363281
# Target log: -119.52778625488281
# Made conversion to -180 to 180 scale
# Getting data from surface data 119 118 to put in wrf 79 74
# Getting data from surface data 119 118 to put in wrf 79 74
# Getting data from surface data 119 118 to put in wrf 79 74
# Working on point 68 in target domain
# Target lat: 37.458194732666016
# Target log: -119.44259643554688
# Made conversion to -180 to 180 scale
# Getting data from surface data 120 120 to put in wrf 79 75
# Getting data from surface data 120 120 to put in wrf 79 75
# Getting data from surface data 120 120 to put in wrf 79 75
# Working on point 69 in target domain
# Target lat: 37.5062255859375
# Target log: -119.35726928710938
# Made conversion to -180 to 180 scale
# Getting data from surface data 122 122 to put in wrf 79 76
# Getting data from surface data 122 122 to put in wrf 79 76
# Getting data from surface data 122 122 to put in wrf 79 76
# Working on point 70 in target domain
# Target lat: 37.55419158935547
# Target log: -119.27182006835938
# Made conversion to -180 to 180 scale
# Getting data from surface data 123 124 to put in wrf 79 77
# Getting data from surface data 123 124 to put in wrf 79 77
# Getting data from surface data 123 124 to put in wrf 79 77
# Working on point 71 in target domain
# Target lat: 37.60207748413086
# Target log: -119.18623352050781
# Made conversion to -180 to 180 scale
# Getting data from surface data 124 126 to put in wrf 79 78
# Getting data from surface data 124 126 to put in wrf 79 78
# Getting data from surface data 124 126 to put in wrf 79 78
# Working on point 72 in target domain
# Target lat: 37.649906158447266
# Target log: -119.10052490234375
# Made conversion to -180 to 180 scale
# Getting data from surface data 125 128 to put in wrf 79 79
# Getting data from surface data 125 128 to put in wrf 79 79
# Getting data from surface data 125 128 to put in wrf 79 79
# Working on point 73 in target domain
# Target lat: 37.62197494506836
# Target log: -119.33233642578125
# Made conversion to -180 to 180 scale
# Getting data from surface data 124 123 to put in wrf 80 77
# Getting data from surface data 124 123 to put in wrf 80 77
# Getting data from surface data 124 123 to put in wrf 80 77
# Working on point 74 in target domain
# Target lat: 37.669925689697266
# Target log: -119.24671936035156
# Made conversion to -180 to 180 scale
# Getting data from surface data 126 125 to put in wrf 80 78
# Getting data from surface data 126 125 to put in wrf 80 78
# Getting data from surface data 126 125 to put in wrf 80 78
# Working on point 75 in target domain
# Target lat: 37.717811584472656
# Target log: -119.16094970703125
# Made conversion to -180 to 180 scale
# Getting data from surface data 127 127 to put in wrf 80 79
# Getting data from surface data 127 127 to put in wrf 80 79
# Getting data from surface data 127 127 to put in wrf 80 79
# CPU times: user 3.32 s, sys: 44.5 ms, total: 3.36 s
# Wall time: 3.37 s

# %% [markdown]
# ## Write to new netcdf

# %%
new_wrf_xds.to_netcdf("surfdata_wrf_CA_hist_16pfts_CMIP6_1981_c220715_updated_ahb_CZ2_domain_122123.nc", format = "NETCDF3_64BIT", mode = "w")

# %% [markdown]
# ## Understanding why the soil data is different at single site CZ2 versus the WRF cell overlapping CZ2 in the regional simulation
#
# Answer: The coordinates at the center of the WRF grid that overlaps CZ2 are slightly different to the coordinates of CZ2 itself. The curstom algorithm above therefore pulls data from the surface data at an adjacent (but not the same) cell as if you input CZ2 coordinates themselves. This is OK and expected. We have to pull soil data algorithmically based on the nearest neighbor to the center of each WRF grid cell. The fact that the vegetation dyanmcis are so different with this small change in soil data is problematic from a model structure perspective.

# %% [markdown]
# ### Closest point to CZ2 in the surface data

# %%
find_nearest_indices(surfdat_path,37.0311,-119.256599)
# Out:
# Made conversion to -180 to 180 scale
# (110, 124)

# %%
surfdat = xr.open_dataset(surfdat_path)
surfdat.PCT_SAND.values[:,110, 124]
# Out:
# array([60., 60., 60., 60., 60., 60., 60., 60., 60., 60.])

# %% [markdown]
# This matches what I used at single point site

# %% [markdown]
# ### Closest point to CZ2 in the updated wrf surface data

# %%
find_nearest_wrf_indices("surfdata_wrf_CA_hist_16pfts_CMIP6_1981_c220715_updated_ahb_CZ2_domain_122123.nc", 37.0311,-119.256599)
# Out:
# (74, 74)

# %%
new_wrf_surf = xr.open_dataset("surfdata_wrf_CA_hist_16pfts_CMIP6_1981_c220715_updated_ahb_CZ2_domain_122123.nc")
new_wrf_surf.PCT_SAND.values[:,74, 74]
# Out:
# array([69.38775635, 69.38775635, 69.38775635, 69.38775635, 69.38775635,
#        69.38775635, 69.38775635, 69.38775635, 69.38775635, 69.38775635])

# %% [markdown]
# The soil data above is different to the single site CZ2 data because when we search through all the wrf grid points we want to update the data for, the coordinates in the center of the wrf grid cell that is closest to CZ2 is not the direct coordinates we use for CZ2. Therefore, the nearest neighbor in the surface data file is different.

# %%
## Closest lat/lon to CZ2 in the wrf grid is
print(find_nearest_wrf_indices(wrf_surfdat_path,37.0311,-119.256599))
wrf_surfdat = xr.open_dataset(wrf_surfdat_path)
print(wrf_surfdat.LATIXY.values[74,74])
print(wrf_surfdat.LONGXY.values[74,74])
# Out:
# (74, 74)
# 37.07170104980469
# -119.22645568847656

# %%
#Which has different soil data
surfdat = xr.open_dataset(surfdat_path)
print(find_nearest_indices(surfdat_path,37.07170104980469,-119.22645568847656))
print(surfdat.PCT_SAND.values[:,111,125])
# Out:
# Made conversion to -180 to 180 scale
# (111, 125)
# [69.38775635 69.38775635 69.38775635 69.38775635 69.38775635 69.38775635
#  69.38775635 69.38775635 69.38775635 69.38775635]
